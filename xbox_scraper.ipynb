# %%
import utils as u
import tables as t

# %%
log = u.LogBook()
u.sort_yaml(log.yaml_file)
# Out:
# No changes found for 'RESIDENT EVIL 2'.
# No changes found for 'RESIDENT EVIL 3 for Xbox'.
# No changes found for 'Dragon Age: Origins'.
# No changes found for 'Halo Infinite (Campaign)'.
# No changes found for 'GUNBIRD'.
# No changes found for '#IDARB'.
# No changes found for '15in1 Solitaire'.
# No changes found for '33 Immortals'.
# No changes found for '8-Ball Pocket'.
# No changes found for '90'' Soccer'.
# No changes found for '9Ball Pocket'.
# No changes found for 'A Little to the Left'.
# No changes found for 'A Memoir Blue'.
# No changes found for 'APFTU'.
# No changes found for 'A Short Hike'.
# No changes found for 'Ancient Phantasma'.
# No changes found for 'Animus - Stand Alone'.
# No changes found for 'ANNO : Mutationem'.
# No changes found for 'Another Crab's Treasure'.
# No changes found for 'Another Dawn'.
# No changes found for 'AntVentor'.
# No changes found for 'Apollo Justice: Ace Attorney Trilogy'.
# No changes found for 'Aragami 2'.
# ...

# %%
log.updated_games
# Out:
# ['Forspoken',
#  'Horror & Sports Pinball',
#  "Who's Your Daddy?!",
#  'The Smurfs 2 : The Prisoner of the Green Stone']

# %%
df = t.make_tables(updated_games=log.updated_games)

df
# Out:
# <style type="text/css">
# #T_b4b50_row0_col0, #T_b4b50_row0_col1, #T_b4b50_row0_col2, #T_b4b50_row0_col3, #T_b4b50_row0_col4, #T_b4b50_row0_col5 {
#   background-color: red;
# }
# #T_b4b50_row1_col0, #T_b4b50_row1_col1, #T_b4b50_row1_col2, #T_b4b50_row1_col3, #T_b4b50_row1_col4, #T_b4b50_row1_col5 {
#   background-color: grey;
# }
# #T_b4b50_row2_col0, #T_b4b50_row2_col1, #T_b4b50_row2_col2, #T_b4b50_row2_col3, #T_b4b50_row2_col4, #T_b4b50_row2_col5 {
#   background-color: orange;
# }
# #T_b4b50_row3_col0, #T_b4b50_row3_col1, #T_b4b50_row3_col2, #T_b4b50_row3_col3, #T_b4b50_row3_col4, #T_b4b50_row3_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_b4b50">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4b50_level0_col0" class="col_heading level0 col0" >Game</th>
#       <th id="T_b4b50_level0_col1" class="col_heading level0 col1" >XboxOne</th>
# ...

# %%
df2 = t.make_tables()

df2
# Out:
# <style type="text/css">
# ...
